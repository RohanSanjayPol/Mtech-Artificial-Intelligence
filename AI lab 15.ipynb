# %%
pip install sorobn
# Out:
# ...
#   Using cached sorobn-0.3.0-py3-none-any.whl (17 kB)
# ...
#      -------------------------------------- 10.9/10.9 MB 409.3 kB/s eta 0:00:00
# ...
#   Using cached vose-0.0.1.tar.gz (129 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   Getting requirements to build wheel did not run successfully.
#   exit code: 1
#
#   [93 lines of output]
#
#   Error compiling Cython file:
#   ------------------------------------------------------------
#   ...
#   cimport numpy as np
#
#   cdef class Sampler:
#
#       cdef int n
#       cdef np.int_t [:] alias
#            ^
#   ------------------------------------------------------------
#
#   vose\sampler.pxd:6:9: 'int_t' is not a type identifier
#
# ...

# %%
 import sorobn as hh
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_37780\1748875942.py in <module>
# ----> 1 import sorobn as hh
#
# ModuleNotFoundError: No module named 'sorobn'
